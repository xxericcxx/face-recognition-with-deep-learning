# %% [markdown]
# # Final project - Modern face recognition with deep learning
#
# Have you noticed that Facebook has developed an uncanny ability to recognize your friends in your photographs? In the old days, Facebook used to make you to tag your friends in photos by clicking on them and typing in their name. Now as soon as you upload a photo, Facebook tags everyone for you like magic. This technology is called face recognition. Facebook’s algorithms are able to recognize your friends’ faces after they have been tagged only a few times. It’s pretty amazing: these algorithms can recognize faces with 98% accuracy, which is pretty much as good as humans can do!
#
# As a human, your brain is wired to recognize faces automatically and instantly. Computers are not capable of doing this, so you have to teach them how to tackle each step in this process. Specifically, a face recognition system goes through four steps: find faces in the image, analyze their facial features, compare against known faces, and make a prediction of the corresponding persons. Here's described the full pipeline.
#
# <img src="figures/summary.gif" style="height:200px;">
#
# ### Table of contents
#
# In this assignment, you will tackle several problems related to face recognition:
# 1. **Face detection**. Look at a picture and find all the faces in it.
# - **Pose estimation**. Understand where the face is turned and correct its pose.
# - **Face encoding**. Pick up unique features from a face that can be used to distinguish it from others.
# - **Face recognition**. Compare the unique features of a face to those of all the people in a database.
# - **Personal dataset**. Build a custom face recognition dataset.
#
# By the end of this notebook, you will have your own face recognition system.

# %% [markdown]
# ### Required packages
#
# Here are the packages you will need during the assignment.
# - [Numpy](http://www.numpy.org)
# - [Keras](https://keras.io)
# - [OpenCV](https://opencv.org)
# - [Dlib](http://dlib.net).
#
# **Note**: In Anaconda Navigator, the package `dlib` can be installed from the **conda-forge** channel.

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import cv2
import dlib
import os
import keras
import sklearn
from keras import layers
from keras import models
from sklearn.preprocessing import OneHotEncoder
import pickle 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC


from sklearn.linear_model import LogisticRegression



from sklearn.neighbors import KNeighborsClassifier  

from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 1. Face detection
#
# The first step in your pipeline is face detection. Obviously you need to locate the faces in a photograph before you can try to tell them apart. If you’ve used any camera in the last 10 years, you’ve probably seen face detection in action. Face detection is a great feature for cameras. When the camera can automatically pick out faces, it can make sure that all the faces are in focus before it takes the picture. But you’ll use it for a different purpose:  finding the areas of the image you want to pass on to the next step in your pipeline.
#
# <img src="figures/detection.jpg" style="height:200px;">

# %% [markdown]
# ### Assignment
#
# Here's what you are required to do for this part of the assignment.
#
# - You are provided with a small dataset of pictures, where each picture contains exactly one face. Extract the faces and their labels (i.e., the person's names). Store them to a new file with the function `drop` in the package `pickle`.
#
#
# -  Normalize the cropped faces (i.e., divide the pixel values by 255), and split them in train set (70%) and test set (30%) with the function `train_test_split` in the package `sklearn`.
#
#
# - Train a small convnet and check its performance on the test set. Remember: don't use the test images for training.
#
#
# - Try to improve the performance of the baseline convnet by using all the tricks you have learned in the course.

# %% [markdown]
# #### Provided functions
#
# Here you will find some useful functions to complete the assignment.

# %%
hog_detector = dlib.get_frontal_face_detector()
cnn_detector = dlib.cnn_face_detection_model_v1('models/mmod_human_face_detector.dat')

def face_locations(image, model="hog"):
    
    if model == "hog":
        detector = hog_detector
        cst = 0
    elif model == "cnn":
        detector = cnn_detector
        cst = 10
            
    matches = detector(image,1)
    rects   = []
    
    for r in matches:
        if model == "cnn":
            r = r.rect
        x = max(r.left(), 0)
        y = max(r.top(), 0)
        w = min(r.right(), image.shape[1]) - x + cst
        h = min(r.bottom(), image.shape[0]) - y + cst
        rects.append((x,y,w,h))
        
    return rects

# %%
def extract_faces(image, model="hog"):
    
    gray  = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    rects = face_locations(gray, model)
    faces = []
    
    for (x,y,w,h) in rects:
        cropped = image[y:y+h, x:x+w, :]
        cropped = cv2.resize(cropped, (128,128))
        faces.append(cropped)
            
    return faces

# %%
def show_grid(faces, figsize=(12,3)):

    n = len(faces)
    cols = 7
    rows = int(np.ceil(n/cols))
    
    fig, ax = plt.subplots(rows,cols, figsize=figsize)

    for r in range(rows):
        for c in range(cols):
            i = r*cols + c
            if i == n:
                 break
            ax[r,c].imshow(faces[i])
            ax[r,c].axis('off')
            #ax[r,c].set_title('size: ' + str(faces[i].shape[:2]))

# %%
def list_images(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"), contains=None):
    
    imagePaths = []
    
    # loop over the directory structure
    for (rootDir, dirNames, filenames) in os.walk(basePath):
        # loop over the filenames in the current directory
        for filename in filenames:
            # if the contains string is not none and the filename does not contain
            # the supplied string, then ignore the file
            if contains is not None and filename.find(contains) == -1:
                continue

            # determine the file extension of the current file
            ext = filename[filename.rfind("."):].lower()

            # check to see if the file is an image and should be processed
            if ext.endswith(validExts):
                # construct the path to the image and yield it
                imagePath = os.path.join(rootDir, filename).replace(" ", "\\ ")
                imagePaths.append(imagePath)
    
    return imagePaths

# %% [markdown]
# #### Hints
#
# The provided function `extract_faces()` applies face detection to a single input image, and returns a list of 128x128 blocks containing the detected faces.

# %%
image = cv2.imread("figures/faces.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,5))
plt.imshow(image)

# %%
faces = extract_faces(image, "hog")  # Replace 'cnn' with 'hog' for faster but less accurate results

# %%
show_grid(faces)

# %% [markdown]
# Moreover, the function `list_images()` locates all the jpeg/png/tiff files in a given folder (including its subfolders).

# %%
imagePaths = list_images("data")

# %%
label1 = []
faces1 = []

# %%
for i in range(len(imagePaths)):
    image = cv2.imread(imagePaths[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    face = extract_faces(image, "cnn")
    if len(face) == 1:
        face = np.squeeze(face)
        faces1.append(face)
        label1.append(imagePaths[i].split('/')[1])

# %%
Y1 = np.array(label1)
X1 = np.array(faces1) / 255
print(X1.shape)
X1_train,X1_test,Y1_train,Y1_test = train_test_split(X1,Y1,test_size = 0.3,random_state = 0)
# Out:
# (207, 128, 128, 3)

# %%
print(X1_train.shape)
# Out:
# (144, 128, 128, 3)

# %%
pic = open(r'/Users/eric/Desktop/E5/ML2/project/FinalProject/new/untitled.txt','wb')
pickle.dump(faces1,pic)
pickle.dump(label1,pic)
pic.close()

# %% [markdown]
# Train a small convnet and check its performance on the test set. Remember: don't use the test images for training.
# Try to improve the performance of the baseline convnet by using all the tricks you have learned in the course.

# %%
input_dim = (128, 128, 3)

# %%
from keras import layers
from keras import models
from sklearn.preprocessing import OneHotEncoder

# %%
enc = OneHotEncoder(sparse = False) 
L1_train = enc.fit_transform(Y1_train.reshape(-1, 1))
L1_test = enc.fit_transform(Y1_test.reshape(-1, 1))

# %%
model = models.Sequential()
model.add( layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_dim) )
model.add( layers.MaxPooling2D((2, 2)) )
model.add( layers.SeparableConv2D(64, (3, 3), activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )
model.add( layers.SeparableConv2D(64, (3, 3), activation='relu') )
model.add(layers.Flatten())
model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001),activation='relu'))
model.add(layers.Dropout(rate = 0.5))
model.add(layers.Dense(32,kernel_regularizer=regularizers.l2(0.001), activation='relu'))
model.add(layers.Dense(6, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X1_train, L1_train, epochs=25, batch_size=16)
# Out:
# Epoch 1/25
# 144/144 [==============================] - 2s 13ms/step - loss: 1.9024 - accuracy: 0.1250
# Epoch 2/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.8454 - accuracy: 0.2431
# Epoch 3/25
# 144/144 [==============================] - 1s 5ms/step - loss: 1.8147 - accuracy: 0.2361
# Epoch 4/25
# 144/144 [==============================] - 1s 5ms/step - loss: 1.7754 - accuracy: 0.2708
# Epoch 5/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.6881 - accuracy: 0.3264
# Epoch 6/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.6146 - accuracy: 0.3889
# Epoch 7/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.5497 - accuracy: 0.4028
# Epoch 8/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.4735 - accuracy: 0.4167
# Epoch 9/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.4399 - accuracy: 0.4375
# Epoch 10/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.3568 - accuracy: 0.5139
# Epoch 11/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.2302 - accuracy: 0.5625
# Epoch 12/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.2373 - accuracy: 0.5903
# Epoch 13/25
# 144/144 [==============================] - 1s 5ms/step - loss: 1.2454 - accuracy: 0.5694
# Epoch 14/25
# 144/144 [==============================] - 1s 5ms/step - loss: 1.2029 - accuracy: 0.5972
# Epoch 15/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.0441 - accuracy: 0.6736
# Epoch 16/25
# 144/144 [==============================] - 1s 6ms/step - loss: 1.0476 - accuracy: 0.6667
# Epoch 17/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.9324 - accuracy: 0.7639
# Epoch 18/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.9674 - accuracy: 0.7500
# Epoch 19/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.9640 - accuracy: 0.6806
# Epoch 20/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.8929 - accuracy: 0.7500
# Epoch 21/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.9926 - accuracy: 0.7014
# Epoch 22/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.9392 - accuracy: 0.7361
# Epoch 23/25
# 144/144 [==============================] - 1s 6ms/step - loss: 0.9891 - accuracy: 0.7569
# Epoch 24/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.9695 - accuracy: 0.7014
# Epoch 25/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.8479 - accuracy: 0.8194

# %%
test_loss, test_acc = model.evaluate(X1_test, L1_test)
print("Test accuracy:", test_acc*100, "%")
# Out:
# 63/63 [==============================] - 0s 4ms/step
# Test accuracy: 76.1904776096344 %

# %% [markdown]
# ## 2. Pose estimation
#
# You have isolated the faces in our image. But now you have to deal with the problem that faces turned different directions look totally different to a computer. To account for this, you will try to warp each picture so that the eyes and lips are always in the same place in the image. More concretely, you are going to use an algorithm called face landmark estimation. The basic idea is to locate 68 specific points (called landmarks) that exist on every face:  the top of the chin, the outside edge of each eye, the inner edge of each eyebrow, etc. Then, you’ll simply rotate, scale and shear the image so that the eyes and mouth are centered as best as possible. This will make face recognition more accurate.
#
# <img src="figures/pose.png" style="height:200px;">

# %% [markdown]
# ### Assignment
#
# Here's what you are required to do for this part of the assignment.
#
# - Further preprocess the face pictures by correcting their pose. You should now have a dataset of cropped, aligned, and normalized faces.
#
#
# - Re-train your convnets on the modified dataset.
#
#
# - Evaluate the performance on the test set, and compare it to the scores obtained with your previously trained convnets.

# %% [markdown]
# #### Provided functions
#
# Here you will find some useful functions to complete the assignment.

# %%
pose68 = dlib.shape_predictor('models/shape_predictor_68_face_landmarks.dat')
pose05 = dlib.shape_predictor('models/shape_predictor_5_face_landmarks.dat')

def face_landmarks(face, model="large"):
    
    if model == "large":
        predictor = pose68
    elif model == "small":
        predictor = pose05
    
    if not isinstance(face, list):
        rect = dlib.rectangle(0,0,face.shape[1],face.shape[0])
        return predictor(face, rect)
    else:
        rect = dlib.rectangle(0,0,face[0].shape[1],face[0].shape[0])
        return [predictor(f,rect) for f in face]

# %%
def shape_to_coords(shape):
    return np.float32([[p.x, p.y] for p in shape.parts()])

# %%
TEMPLATE = np.float32([
    (0.0792396913815, 0.339223741112), (0.0829219487236, 0.456955367943),
    (0.0967927109165, 0.575648016728), (0.122141515615, 0.691921601066),
    (0.168687863544, 0.800341263616), (0.239789390707, 0.895732504778),
    (0.325662452515, 0.977068762493), (0.422318282013, 1.04329000149),
    (0.531777802068, 1.06080371126), (0.641296298053, 1.03981924107),
    (0.738105872266, 0.972268833998), (0.824444363295, 0.889624082279),
    (0.894792677532, 0.792494155836), (0.939395486253, 0.681546643421),
    (0.96111933829, 0.562238253072), (0.970579841181, 0.441758925744),
    (0.971193274221, 0.322118743967), (0.163846223133, 0.249151738053),
    (0.21780354657, 0.204255863861), (0.291299351124, 0.192367318323),
    (0.367460241458, 0.203582210627), (0.4392945113, 0.233135599851),
    (0.586445962425, 0.228141644834), (0.660152671635, 0.195923841854),
    (0.737466449096, 0.182360984545), (0.813236546239, 0.192828009114),
    (0.8707571886, 0.235293377042), (0.51534533827, 0.31863546193),
    (0.516221448289, 0.396200446263), (0.517118861835, 0.473797687758),
    (0.51816430343, 0.553157797772), (0.433701156035, 0.604054457668),
    (0.475501237769, 0.62076344024), (0.520712933176, 0.634268222208),
    (0.565874114041, 0.618796581487), (0.607054002672, 0.60157671656),
    (0.252418718401, 0.331052263829), (0.298663015648, 0.302646354002),
    (0.355749724218, 0.303020650651), (0.403718978315, 0.33867711083),
    (0.352507175597, 0.349987615384), (0.296791759886, 0.350478978225),
    (0.631326076346, 0.334136672344), (0.679073381078, 0.29645404267),
    (0.73597236153, 0.294721285802), (0.782865376271, 0.321305281656),
    (0.740312274764, 0.341849376713), (0.68499850091, 0.343734332172),
    (0.353167761422, 0.746189164237), (0.414587777921, 0.719053835073),
    (0.477677654595, 0.706835892494), (0.522732900812, 0.717092275768),
    (0.569832064287, 0.705414478982), (0.635195811927, 0.71565572516),
    (0.69951672331, 0.739419187253), (0.639447159575, 0.805236879972),
    (0.576410514055, 0.835436670169), (0.525398405766, 0.841706377792),
    (0.47641545769, 0.837505914975), (0.41379548902, 0.810045601727),
    (0.380084785646, 0.749979603086), (0.477955996282, 0.74513234612),
    (0.523389793327, 0.748924302636), (0.571057789237, 0.74332894691),
    (0.672409137852, 0.744177032192), (0.572539621444, 0.776609286626),
    (0.5240106503, 0.783370783245), (0.477561227414, 0.778476346951)])

TPL_MIN, TPL_MAX = np.min(TEMPLATE, axis=0), np.max(TEMPLATE, axis=0)
MINMAX_TEMPLATE = (TEMPLATE - TPL_MIN) / (TPL_MAX - TPL_MIN)

INNER_EYES_AND_BOTTOM_LIP = np.array([39, 42, 57])
OUTER_EYES_AND_NOSE = np.array([36, 45, 33])

# %%
def align_faces(images, landmarks, idx=INNER_EYES_AND_BOTTOM_LIP):
    faces = []
    for (img, marks) in zip(images, landmarks):
        imgDim = img.shape[0]
        coords = shape_to_coords(marks)
        H = cv2.getAffineTransform(coords[idx], imgDim * MINMAX_TEMPLATE[idx])
        warped = cv2.warpAffine(img, H, (imgDim, imgDim))
        faces.append(warped)
    return faces

# %% [markdown]
# #### Hints
#
# The provided function `face_landmarks()` computes the landmarks for a list of cropped faces.

# %%
landmarks = face_landmarks(faces)

# %%
new_faces = []
for (face,shape) in zip(faces, landmarks):
    canvas = face.copy()
    coords = shape_to_coords(shape)
    for p in coords:
        cv2.circle(canvas, (p[0],p[1]), 1, (0, 0, 255), -1)
    new_faces.append(canvas)

# %%
show_grid(new_faces, figsize=(15,5))

# %%
aligned = align_faces(faces, landmarks)

# %%
show_grid(aligned, figsize=(15,5))

# %%
plt.imshow( np.stack(aligned, axis=3).astype(np.float).mean(axis=3)/255 )

# %%
imagePaths = list_images("data")

# %%
label2 = []
faces2 = []

# %%
for i in range(len(imagePaths)):
    image = cv2.imread(imagePaths[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    face = extract_faces(image, "cnn")
    if len(face) == 1:
        landmarks = face_landmarks(face)
        aligned = align_faces(face, landmarks)
        face = np.squeeze(face)
        faces2.append(face)
        label2.append(imagePaths[i].split('/')[1])

# %%
Y2 = np.array(label2)
X2 = np.array(faces2) / 255
print(X2.shape)
# Out:
# (207, 128, 128, 3)

# %%
from sklearn.model_selection import train_test_split
X2_train,X2_test,Y2_train,Y2_test = train_test_split(X2,Y2,test_size = 0.3,random_state = 0)

# %%
enc = OneHotEncoder(sparse = False) 
L2_train = enc.fit_transform(Y2_train.reshape(-1, 1))
L2_test = enc.fit_transform(Y2_test.reshape(-1, 1))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X2_train, L2_train, epochs=25, batch_size=32)
# Out:
# Epoch 1/25
# 144/144 [==============================] - 2s 13ms/step - loss: 0.4982 - accuracy: 0.8819
# Epoch 2/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4752 - accuracy: 0.8889
# Epoch 3/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4230 - accuracy: 0.9375
# Epoch 4/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.5082 - accuracy: 0.8819
# Epoch 5/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4428 - accuracy: 0.9236
# Epoch 6/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4481 - accuracy: 0.9028
# Epoch 7/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3436 - accuracy: 0.9583
# Epoch 8/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4146 - accuracy: 0.9236
# Epoch 9/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4865 - accuracy: 0.8889
# Epoch 10/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4323 - accuracy: 0.8889
# Epoch 11/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4048 - accuracy: 0.9306
# Epoch 12/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3804 - accuracy: 0.9236
# Epoch 13/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3480 - accuracy: 0.9653
# Epoch 14/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3492 - accuracy: 0.9375
# Epoch 15/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3123 - accuracy: 0.9653
# Epoch 16/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3479 - accuracy: 0.9444
# Epoch 17/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3623 - accuracy: 0.9653
# Epoch 18/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.2739 - accuracy: 0.9653
# Epoch 19/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3911 - accuracy: 0.9375
# Epoch 20/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3150 - accuracy: 0.9375
# Epoch 21/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3246 - accuracy: 0.9583
# Epoch 22/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3656 - accuracy: 0.9375
# Epoch 23/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3439 - accuracy: 0.9236
# Epoch 24/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3237 - accuracy: 0.9583
# Epoch 25/25
# 144/144 [==============================] - 1s 5ms/step - loss: 0.3903 - accuracy: 0.9375

# %%
test_loss, test_acc = model.evaluate(X2_test, L2_test)
print("Test accuracy:", test_acc*100, "%")
# Out:
# 63/63 [==============================] - 0s 4ms/step
# Test accuracy: 82.53968358039856 %

# %% [markdown]
# ## 3. Face encoding
#
# The simplest approach to face recognition is to directly classify an unknown face with a convnet trained on your database of tagged people. Seems like a pretty good idea, right? There’s actually a huge problem with that approach. A site like Facebook with billions of users and a trillion photos can’t possibly train such a big convnet. That would take way too long. What you need is a way to extract a few basic measurements from each face, which you can then use to quickly compare the unknown face with your database. For example, you might measure the size of each ear, the spacing between the eyes, the length of the nose, etc. However, it turns out that the measurements that seem obvious to us humans (like eye color) don’t really make sense to a computer looking at individual pixels in an image. Researchers have discovered that the most accurate approach is to let the computer figure out the measurements to collect itself. Deep learning does a better job than humans at figuring out which parts of a face are important to measure.
#
# The solution is to train a convnet. But instead of training the network to classify pictures, it is trained to generate 128 measurements for each face. The training process works by looking at 3 face images at a time: the picture of a known person, another picture of the same known person, and a picture of a totally different person. Then, the algorithm looks at the measurements currently generated for each of those three images. It tweaks the neural network slightly to make sure that the measurements generated for the same person are slightly closer, and the measurements for different persons are slightly further apart. After repeating this step millions of times for millions of images of thousands of different people, the convnet learns to generate 128 measurements for each person.
#
# <img src="figures/triplet.png" style="height:400px;">
#
# This process of training a convnet to output face encodings requires a lot of data and computer power. Even with an expensive GPU, it takes about 24 hours of continuous training to get good accuracy. But once the network has been trained, it can generate measurements for any face, even ones it has never seen before! So this step only needs to be done once. Fortunately, the people at [OpenFace](https://cmusatyalab.github.io/openface/) already did this and they published several trained networks which you can directly use. So all you need to do is run your face images through their pre-trained network to get the 128 measurements for each face.
#
# <img src="figures/encoding.png" style="height:300px;">

# %% [markdown]
# ### Assignment
#
# Here's what you are required to do for this part of the assignment.
#
# - Preprocess the cropped faces by encoding them. You should now have a dataset of cropped and encoded faces.
#
#
# - Train a neural network on the modified dataset. Since the encoded faces are just 128-length vectors, **you don't need a convnet**. Use a regular neural network with a series of fully-connected layers.
#
#
# - Evaluate the performance on the test set, and compare it to the scores obtained with your previously trained convnets.

# %% [markdown]
# #### Provided functions

# %%
cnn_encoder = dlib.face_recognition_model_v1('models/dlib_face_recognition_resnet_model_v1.dat')

def face_encoder(faces):
    
    landmarks = face_landmarks(faces)
    
    if not isinstance(faces, list):
        return np.array(cnn_encoder.compute_face_descriptor(faces,landmarks))
    else:
        return np.array([cnn_encoder.compute_face_descriptor(f,l) for f,l in zip(faces,landmarks)])

# %% [markdown]
# #### Hints
#
# The provided function `face_encoder()` computes the encodings for a list of cropped faces. Alignment and normalization are handled internally.

# %%
encoded_faces = face_encoder(faces)

# %%
plt.plot(encoded_faces[0])

# %%
encode_faces = face_encoder(faces1)

# %%
encode_faces.shape
# Out:
# (207, 128)

# %%
X3_train,X3_test = train_test_split(encode_faces,test_size = 0.3,random_state = 0)

# %%
print(X3_train.shape)
# Out:
# (144, 128)

# %%
model = models.Sequential()
model.add(layers.Dense(64, input_dim=128,activation='relu'))
model.add(layers.Dense(64,  activation='relu'))
model.add(layers.Dropout(rate = 0.5))
model.add(layers.Dense(64,  activation='relu'))
model.add(layers.Dense(6, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X3_train, L1_train, epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 144/144 [==============================] - 1s 5ms/step - loss: 1.7884 - accuracy: 0.2292
# Epoch 2/30
# 144/144 [==============================] - 0s 159us/step - loss: 1.7495 - accuracy: 0.2847
# Epoch 3/30
# 144/144 [==============================] - 0s 165us/step - loss: 1.7329 - accuracy: 0.2639
# Epoch 4/30
# 144/144 [==============================] - 0s 159us/step - loss: 1.6915 - accuracy: 0.2639
# Epoch 5/30
# 144/144 [==============================] - 0s 164us/step - loss: 1.6426 - accuracy: 0.2639
# Epoch 6/30
# 144/144 [==============================] - 0s 161us/step - loss: 1.6119 - accuracy: 0.2708
# Epoch 7/30
# 144/144 [==============================] - 0s 165us/step - loss: 1.5822 - accuracy: 0.2639
# Epoch 8/30
# 144/144 [==============================] - 0s 164us/step - loss: 1.4988 - accuracy: 0.3056
# Epoch 9/30
# 144/144 [==============================] - 0s 161us/step - loss: 1.4439 - accuracy: 0.3472
# Epoch 10/30
# 144/144 [==============================] - 0s 189us/step - loss: 1.3757 - accuracy: 0.4375
# Epoch 11/30
# 144/144 [==============================] - 0s 310us/step - loss: 1.3025 - accuracy: 0.4375
# Epoch 12/30
# 144/144 [==============================] - 0s 167us/step - loss: 1.2343 - accuracy: 0.5972
# Epoch 13/30
# 144/144 [==============================] - 0s 161us/step - loss: 1.1234 - accuracy: 0.6389
# Epoch 14/30
# 144/144 [==============================] - 0s 163us/step - loss: 1.0353 - accuracy: 0.7153
# Epoch 15/30
# 144/144 [==============================] - 0s 159us/step - loss: 0.9459 - accuracy: 0.7431
# Epoch 16/30
# 144/144 [==============================] - 0s 158us/step - loss: 0.8353 - accuracy: 0.7986
# Epoch 17/30
# 144/144 [==============================] - 0s 157us/step - loss: 0.7854 - accuracy: 0.8125
# Epoch 18/30
# 144/144 [==============================] - 0s 163us/step - loss: 0.6541 - accuracy: 0.8681
# Epoch 19/30
# 144/144 [==============================] - 0s 162us/step - loss: 0.6131 - accuracy: 0.8681
# Epoch 20/30
# 144/144 [==============================] - 0s 160us/step - loss: 0.5731 - accuracy: 0.8333
# Epoch 21/30
# 144/144 [==============================] - 0s 168us/step - loss: 0.4663 - accuracy: 0.8889
# Epoch 22/30
# 144/144 [==============================] - 0s 162us/step - loss: 0.4378 - accuracy: 0.9236
# Epoch 23/30
# 144/144 [==============================] - 0s 160us/step - loss: 0.4034 - accuracy: 0.8958
# Epoch 24/30
# 144/144 [==============================] - 0s 166us/step - loss: 0.3432 - accuracy: 0.9514
# Epoch 25/30
# 144/144 [==============================] - 0s 158us/step - loss: 0.3116 - accuracy: 0.9444
# Epoch 26/30
# 144/144 [==============================] - 0s 165us/step - loss: 0.2980 - accuracy: 0.9236
# Epoch 27/30
# 144/144 [==============================] - 0s 160us/step - loss: 0.2545 - accuracy: 0.9583
# Epoch 28/30
# 144/144 [==============================] - 0s 166us/step - loss: 0.2328 - accuracy: 0.9514
# Epoch 29/30
# 144/144 [==============================] - 0s 158us/step - loss: 0.1731 - accuracy: 0.9722
# Epoch 30/30
# 144/144 [==============================] - 0s 157us/step - loss: 0.1974 - accuracy: 0.9583

# %%
test_loss, test_acc = model.evaluate(X3_test, L1_test)
print("Test accuracy:", test_acc*100, "%")
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Test accuracy: 96.82539701461792 %

# %% [markdown]
# ## 4. Face recognition
#
# This last step is actually the easiest one in the whole process. All you have to do is find the person in your database of known people who has the closest measurements to some test image. You can do that by using any machine learning classification algorithm, such as neaural network (as you did in the previous section), logistic regression, SVM, nearest neighbours, etc. All you need to do is training a classifier that can take in the measurements from a new test image, and tells which known person is the closest match. Running this classifier must only take milliseconds, so that you can apply it to video sequences.
#
# <img src="figures/test.gif" style="height:300px;">

# %% [markdown]
# ### Assignment
#
# Here's what you are required to do for this part of the assignment.
#
# -  Train several classifiers (logistic regression, SVM, kNN, neural network) on the dataset of encoded faces (you can use the package `scikit-learn`).
#
# - Evaluate their performance on the test set, in terms of accuracy and speed.
#
# - Finally, run your best classifier on the test images and video available in the `test` folder.

# %% [markdown]
# #### Provided functions

# %%
def process_frame(image, mode="fast"):
    
    # face detection
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    if mode == "fast":
        matches = hog_detector(gray,1)
    else:
        matches = cnn_detector(gray,1)
        matches = [m.rect for m in matches]
        
    for rect in matches:
        
        # face landmarks
        landmarks = pose68(gray, rect)
        
        # face encoding
        encoding = cnn_encoder.compute_face_descriptor(image, landmarks)
        a = np.array(encoding).reshape(1,128)
        label = str(model_knn.predict(a))
        
        # draw box
        cv2.rectangle(image, (rect.left(), rect.top()), (rect.right(), rect.bottom()), (0, 255, 0), 2)
        y = rect.top() - 15 if rect.top() - 15 > 15 else rect.bottom() + 25
        cv2.putText(image, label, (rect.left(), y), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0, 255, 0), 2)
        
    return image

# %%
def process_movie(video_name, mode="fast"):
    
    video  = cv2.VideoCapture(video_name)
    
    try:
        
        while True:

            # Grab a single frame of video
            ret, frame = video.read()
            
            # Resize frame of video for faster processing
            frame = cv2.resize(frame, (0, 0), fx=0.5, fy=0.5)

            # Quit when the input video file ends or key "Q" is pressed
            key = cv2.waitKey(1) & 0xFF
            if not ret or key == ord("q"):
                break

            # Process frame
            image = process_frame(frame, mode)

            # Display the resulting image
            cv2.imshow('Video', image)
    
    finally:
        video.release()
        cv2.destroyAllWindows()
        print("Video released")

# %% [markdown]
# #### Hints
#
# The provided function `process_frame()` detects and encodes all the faces in the input image.

# %%
image = cv2.imread("test/example_01.png")

# %%
processed = process_frame(image.copy())
processed = cv2.cvtColor(processed, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,5))
plt.imshow(processed)

# %% [markdown]
# The provided function `process_frame()` detects and encodes the faces in the input video.

# %%
process_movie("test/lunch_scene.mp4")
# Out:
# Video released
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-266-d5f78da6d32b> in <module>
# ----> 1 process_movie("test/lunch_scene.mp4")
#
# <ipython-input-262-308ab1151c8f> in process_movie(video_name, mode)
#      11
#      12             # Resize frame of video for faster processing
# ---> 13             frame = cv2.resize(frame, (0, 0), fx=0.5, fy=0.5)
#      14
#      15             # Quit when the input video file ends or key "Q" is pressed
#
# error: OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-4jcifzim/opencv/modules/imgproc/src/resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# The special input `0` can be used to access the webcam.

# %%
process_movie(0)

# %%
model_log = sklearn.linear_model.LogisticRegression()

# %%
model_log.fit(X3_train,Y1_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pre_log = model_log.predict(X3_test)

# %%
model_log.score(X3_test , Y1_test)
# Out:
# 0.9682539682539683

# %%
model_svm =SVC(kernel='linear',probability=True)

# %%
model_svm.fit(X3_train,Y1_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
model_svm.score(X3_test,Y1_test)
# Out:
# 0.9682539682539683

# %%
model_knn = KNeighborsClassifier(n_neighbors=5)

# %%
model_knn.fit(X3_train,Y1_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
model_knn.score(X3_test,Y1_test)
# Out:
# 0.9682539682539683

# %% [markdown]
# ## 5. Build a custom dataset
#
# So far, you have used a pre-curated dataset, where somebody did the hard work of gathering and labeling the images for you. Now, you will tackle the problem of recognizing faces of yourselves, friends, family members, colleagues, etc. To accomplish this, you need to gather examples of faces you want to recognize. You can enroll facial pictures via a webcam attached to your computer.
#
# ### Assignment
# Here's what you are required to do for this part of the assignment.
#
# - Use your webcam to enroll face pictures of yourself, your friends, etc. To do so, you need to open the webcam, detect faces in the video stream, and save the captured face images to disk.
#
#
# - Build a dataset of reasonable size: a group of 10-15 people with 50-100 face pictures each, taken in different conditions of light, angle, emotion, etc.
#
#
# - Apply the previously developed pipeline to build your own personalized face recognition system.

# %%
myimagePaths = list_images("mydata")

# %%
mylabel1 = []
myfaces1 = []

# %%
for i in range(len(myimagePaths)):
    image = cv2.imread(myimagePaths[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    face = extract_faces(image, "hog")
    if len(face) == 1:
        face = np.squeeze(face)
        myfaces1.append(face)
        mylabel1.append(myimagePaths[i].split('/')[1])

# %%
myY1 = np.array(mylabel1)
myX1 = np.array(myfaces1) / 255
myX1 = np.squeeze(myX1)

# %%
from sklearn.model_selection import train_test_split
myX1_train,myX1_test,myY1_train,myY1_test = train_test_split(myX1,myY1,test_size = 0.3,random_state = 0)

# %%
input_dim = (128, 128, 3)

# %%
enc = OneHotEncoder(sparse = False) 
myL1_train = enc.fit_transform(myY1_train.reshape(-1, 1))
myL1_test = enc.fit_transform(myY1_test.reshape(-1, 1))

# %%
model = models.Sequential()
model.add( layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_dim) )
model.add( layers.MaxPooling2D((2, 2)) )
model.add( layers.SeparableConv2D(64, (3, 3), activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )
model.add( layers.SeparableConv2D(64, (3, 3), activation='relu') )
model.add(layers.Flatten())
model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001),activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(11, activation='softmax'))#because i have 11 categories now, so i set 11 here

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 
model.fit(myX1_train, myL1_train, epochs=25, batch_size=64)
# Out:
# Epoch 1/25
# 361/361 [==============================] - 3s 7ms/step - loss: 2.4844 - accuracy: 0.0886
# Epoch 2/25
# 361/361 [==============================] - 1s 4ms/step - loss: 2.4099 - accuracy: 0.1219
# Epoch 3/25
# 361/361 [==============================] - 1s 4ms/step - loss: 2.3790 - accuracy: 0.1440
# Epoch 4/25
# 361/361 [==============================] - 1s 4ms/step - loss: 2.3284 - accuracy: 0.1801
# Epoch 5/25
# 361/361 [==============================] - 1s 4ms/step - loss: 2.2750 - accuracy: 0.2216
# Epoch 6/25
# 361/361 [==============================] - 2s 4ms/step - loss: 2.1836 - accuracy: 0.2521
# Epoch 7/25
# 361/361 [==============================] - 1s 4ms/step - loss: 2.0417 - accuracy: 0.3546
# Epoch 8/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.9103 - accuracy: 0.3684
# Epoch 9/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.8995 - accuracy: 0.3518
# Epoch 10/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.7059 - accuracy: 0.4460
# Epoch 11/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.5569 - accuracy: 0.5346
# Epoch 12/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.5255 - accuracy: 0.5125
# Epoch 13/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.3903 - accuracy: 0.5651
# Epoch 14/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.2537 - accuracy: 0.6288
# Epoch 15/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.2089 - accuracy: 0.6565
# Epoch 16/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.1438 - accuracy: 0.6981
# Epoch 17/25
# 361/361 [==============================] - 1s 4ms/step - loss: 1.0073 - accuracy: 0.7341
# Epoch 18/25
# 361/361 [==============================] - 1s 4ms/step - loss: 0.9651 - accuracy: 0.7535
# Epoch 19/25
# 361/361 [==============================] - 1s 4ms/step - loss: 0.8792 - accuracy: 0.7784
# Epoch 20/25
# 361/361 [==============================] - 1s 4ms/step - loss: 0.7867 - accuracy: 0.8227
# Epoch 21/25
# 361/361 [==============================] - 1s 4ms/step - loss: 0.7433 - accuracy: 0.8199
# Epoch 22/25
# 361/361 [==============================] - 1s 4ms/step - loss: 0.6484 - accuracy: 0.9003
# Epoch 23/25
# 361/361 [==============================] - 1s 4ms/step - loss: 0.5603 - accuracy: 0.9141
# Epoch 24/25
# 361/361 [==============================] - 1s 4ms/step - loss: 0.4859 - accuracy: 0.9363
# Epoch 25/25
# 361/361 [==============================] - 1s 4ms/step - loss: 0.4280 - accuracy: 0.9640

# %%
test_loss, test_acc = model.evaluate(myX1_test, myL1_test)
print("Test accuracy:", test_acc*100, "%")
# Out:
# 156/156 [==============================] - 0s 2ms/step
# Test accuracy: 42.307692766189575 %

# %%
myencode_faces = face_encoder(myfaces1)

# %%
myX3_train,myX3_test = train_test_split(myencode_faces,test_size = 0.3,random_state = 0)

# %%
model = models.Sequential()
model.add(layers.Dense(64, input_dim=128,activation='relu'))
model.add(layers.Dropout(rate = 0.5))
model.add(layers.Dense(8,  activation='relu'))
model.add(layers.Dense(11, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # ADD CODE HERE
model.fit(myX3_train, myL1_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 361/361 [==============================] - 1s 2ms/step - loss: 0.3457 - accuracy: 0.9030
# Epoch 2/5
# 361/361 [==============================] - 0s 116us/step - loss: 0.3800 - accuracy: 0.8892
# Epoch 3/5
# 361/361 [==============================] - 0s 117us/step - loss: 0.3427 - accuracy: 0.9197
# Epoch 4/5
# 361/361 [==============================] - 0s 120us/step - loss: 0.3278 - accuracy: 0.9003
# Epoch 5/5
# 361/361 [==============================] - 0s 118us/step - loss: 0.3511 - accuracy: 0.9058

# %%
test_loss, test_acc = model.evaluate(myX3_test, myL1_test)
print("Test accuracy:", test_acc*100, "%")
# Out:
# 156/156 [==============================] - 0s 942us/step
# Test accuracy: 94.2307710647583 %

# %% [markdown]
# KNN

# %%
mymodel_knn = KNeighborsClassifier(n_neighbors=5)

# %%
mymodel_knn.fit(myX3_train,myY1_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
mymodel_knn.predict(myX3_test)
# Out:
# array(['Lana', 'ZhouRunfa', 'Fan', 'Lana', 'ChenLi', 'GeYou', 'ChenLi',
#        'Downey', 'JiangWen', 'TongYao', 'LiuNeng', 'LiuNeng', 'Downey',
#        'Jessica', 'ChenLi', 'TongYao', 'LiuNeng', 'Downey', 'LiuNeng',
#        'Downey', 'GeYou', 'GD', 'JiangWen', 'Fan', 'JiangWen', 'Lana',
#        'GeYou', 'Downey', 'GD', 'GeYou', 'GeYou', 'ZhouRunfa', 'Fan',
#        'Downey', 'JiangWen', 'Lana', 'Jessica', 'ChenLi', 'Lana',
#        'Downey', 'Downey', 'Jessica', 'GD', 'Jessica', 'GD', 'ChenLi',
#        'JiangWen', 'Jessica', 'ChenLi', 'Fan', 'ChenLi', 'Fan', 'Jessica',
#        'GD', 'Fan', 'GeYou', 'TongYao', 'GeYou', 'Fan', 'Lana', 'TongYao',
#        'Jessica', 'JiangWen', 'Lana', 'Lana', 'Lana', 'Jessica',
#        'JiangWen', 'TongYao', 'Downey', 'Lana', 'GD', 'GeYou', 'JiangWen',
#        'ChenLi', 'JiangWen', 'ZhouRunfa', 'TongYao', 'Fan', 'TongYao',
#        'TongYao', 'LiuNeng', 'Lana', 'LiuNeng', 'Jessica', 'Downey',
#        'Downey', 'GD', 'JiangWen', 'Jessica', 'Downey', 'Lana', 'TongYao',
#        'GD', 'ZhouRunfa', 'Downey', 'JiangWen', 'TongYao', 'GD', 'ChenLi',
#        'TongYao', 'Jessica', 'ChenLi', 'LiuNeng', 'JiangWen', 'TongYao',
#        'ZhouRunfa', 'TongYao', 'Lana', 'ChenLi', 'GD', 'TongYao',
#        'ZhouRunfa', 'GeYou', 'ZhouRunfa', 'LiuNeng', 'Lana', 'GD',
#        'JiangWen', 'LiuNeng', 'GeYou', 'ChenLi', 'Lana', 'GeYou', 'GD',
#        'ZhouRunfa', 'Downey', 'ZhouRunfa', 'Lana', 'GD', 'Downey',
#        'Jessica', 'Jessica', 'LiuNeng', 'TongYao', 'LiuNeng', 'JiangWen',
#        'ZhouRunfa', 'Downey', 'Lana', 'Lana', 'TongYao', 'ChenLi',
#        'JiangWen', 'GeYou', 'JiangWen', 'Downey', 'ZhouRunfa', 'JiangWen',
#        'TongYao', 'TongYao', 'GeYou', 'Lana', 'GeYou', 'GD', 'Lana'],
#       dtype='<U9')

# %%
mymodel_knn.score(myX3_test,myY1_test)
# Out:
# 0.9743589743589743

# %%
def process_frame(image, mode="fast"):
    
    # face detection
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    if mode == "fast":
        matches = hog_detector(gray,1)
    else:
        matches = cnn_detector(gray,1)
        matches = [m.rect for m in matches]
        
    for rect in matches:
        
        # face landmarks
        landmarks = pose68(gray, rect)
        
        # face encoding
        encoding = cnn_encoder.compute_face_descriptor(image, landmarks)
        a = np.array(encoding).reshape(1,128)
        label = str(mymodel_knn.predict(a))
        
        # draw box
        cv2.rectangle(image, (rect.left(), rect.top()), (rect.right(), rect.bottom()), (0, 255, 0), 2)
        y = rect.top() - 15 if rect.top() - 15 > 15 else rect.bottom() + 25
        cv2.putText(image, label, (rect.left(), y), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0, 255, 0), 2)
        
    return image

# %%
image = cv2.imread("mydata/test1.png")

# %%
processed = process_frame(image.copy())
processed = cv2.cvtColor(processed, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,5))
plt.imshow(processed)

# %%
process_movie("mydata/movie.flv")
# Out:
# Video released
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-402-246fe35c2a34> in <module>
# ----> 1 process_movie("mydata/movie.flv")
#
# <ipython-input-338-308ab1151c8f> in process_movie(video_name, mode)
#      11
#      12             # Resize frame of video for faster processing
# ---> 13             frame = cv2.resize(frame, (0, 0), fx=0.5, fy=0.5)
#      14
#      15             # Quit when the input video file ends or key "Q" is pressed
#
# error: OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-4jcifzim/opencv/modules/imgproc/src/resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
